# %%
import os
import ffmpeg
import pandas as pd
import tkinter as tk
from tkinter import filedialog

# %%
root = tk.Tk()
root.withdraw()  

coordinates = filedialog.askopenfilename(title = "Select file",filetypes = (("CSV Files","*.csv"),))

# %%
square_size = input("Enter cropped video size: ")
# Out:
# Enter video extension from phonea
# Enter cropped video size: 480

# %%
def trim_byhour_cropped_avi(coordinates, square_size):
    
    #read each video file in the Results.csv file
    df = pd.read_csv(coordinates)
    dir_path = os.path.dirname(coordinates)
    
    #extract video names from list
    video = df['Label'].tolist()
    video = list(set(video))
    
    vid_extensions = [".MOV", ".mp4", ".MP4", ".mov"]
    
    for a in video: 
        name, extension = os.path.splitext(a)
        
        for (root, dirs, file) in os.walk(dir_path):
            for f in file:
                if name in f:
                    name_1, extension_1 = os.path.splitext(f)
                    if extension_1 in vid_extensions:
                        video_file = f
                
        video_path = os.path.join(dir_path, video_file)
        
        #figure out how many hours long the movie is
        probe = ffmpeg.probe(video_path)
        stream = probe['streams'][0]
        duration = stream['duration']
        hr = int(float(duration)/60)

        #extract start times from the same video:
        df_1 = df[df['Label']==a]
        start_time = df_1["start"].tolist()
        start_time = list(set(start_time))
    
        #loop through start time
        for s in start_time:
            #check how many plates have the same start time in the same video
            df_2 = df_1.loc[df_1["start"] == s]
            df_2.reset_index(inplace=True)
            i = len(df_2)
            
            #make folder to store the extracted movies
            new_folder = name+'_'+str(s)
            new_path = os.path.join(dir_path,new_folder)
            os.mkdir(new_path)    

            for n in range(i):
                os.mkdir(os.path.join(new_path,new_folder+"_"+str(n+1)))           
            
            #extract movies
            pts = "PTS-STARTPTS"
            h=1

            while h <= hr:      
                input_stream = ffmpeg.input(video_path, ss=h*60-(5)+s)
                trimmed = input_stream.trim(duration = 10).setpts(pts)
                
                for m in range(i):
                    cropped_1 = ffmpeg.filter(trimmed, 'crop', w=square_size, h=square_size, x=df_2["X"][m], y=df_2["Y"][m])
                    out_vid_1 = ffmpeg.output(cropped_1, new_path+'/'+new_folder+"_"+str(m+1)+'/'+new_folder+"_"+str(m+1)+"_{0:0=2d}".format(h)+'.avi', vcodec='rawvideo', preset='veryfast')
                    out_vid_1.run()       
        
                h += 1

# %%
trim_byhour_cropped_avi(coordinates, 480)
# Out:
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kyoung/Downloads/TC_00012.MOV':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2022-11-16T07:45:20.000000Z
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#   Duration: 00:22:23.20, start: 0.000000, bitrate: 23680 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x1080, 23677 kb/s, 30 fps, 30 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       creation_time   : 2022-11-16T07:45:21.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
# Codec AVOption preset (Set the encoding preset (cf. x264 --fullhelp)) specified for output file #0 (/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_1/TC_00012_0_1_01.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 (h264) -> trim
#   crop -> Stream #0:0 (rawvideo)
# Press [q] to stop, [?] for help
# Output #0, avi, to '/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_1/TC_00012_0_1_01.avi':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 480x480, q=2-31, 82944 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       encoder         : Lavc58.91.100 rawvideo
# frame=  300 fps= 82 q=-0.0 Lsize=  101263kB time=00:00:10.00 bitrate=82954.3kbits/s speed=2.72x
# video:101250kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.012429%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kyoung/Downloads/TC_00012.MOV':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2022-11-16T07:45:20.000000Z
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#   Duration: 00:22:23.20, start: 0.000000, bitrate: 23680 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x1080, 23677 kb/s, 30 fps, 30 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       creation_time   : 2022-11-16T07:45:21.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
# Codec AVOption preset (Set the encoding preset (cf. x264 --fullhelp)) specified for output file #0 (/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_2/TC_00012_0_2_01.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 (h264) -> trim
#   crop -> Stream #0:0 (rawvideo)
# Press [q] to stop, [?] for help
# Output #0, avi, to '/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_2/TC_00012_0_2_01.avi':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 480x480, q=2-31, 82944 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       encoder         : Lavc58.91.100 rawvideo
# frame=  300 fps=106 q=-0.0 Lsize=  101263kB time=00:00:10.00 bitrate=82954.3kbits/s speed=3.52x
# video:101250kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.012429%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kyoung/Downloads/TC_00012.MOV':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2022-11-16T07:45:20.000000Z
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#   Duration: 00:22:23.20, start: 0.000000, bitrate: 23680 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x1080, 23677 kb/s, 30 fps, 30 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       creation_time   : 2022-11-16T07:45:21.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
# Codec AVOption preset (Set the encoding preset (cf. x264 --fullhelp)) specified for output file #0 (/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_1/TC_00012_0_1_02.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 (h264) -> trim
#   crop -> Stream #0:0 (rawvideo)
# Press [q] to stop, [?] for help
# Output #0, avi, to '/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_1/TC_00012_0_1_02.avi':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 480x480, q=2-31, 82944 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       encoder         : Lavc58.91.100 rawvideo
# frame=  300 fps=118 q=-0.0 Lsize=  101263kB time=00:00:10.00 bitrate=82954.3kbits/s speed=3.93x
# video:101250kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.012429%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kyoung/Downloads/TC_00012.MOV':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2022-11-16T07:45:20.000000Z
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#   Duration: 00:22:23.20, start: 0.000000, bitrate: 23680 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x1080, 23677 kb/s, 30 fps, 30 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       creation_time   : 2022-11-16T07:45:21.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
# Codec AVOption preset (Set the encoding preset (cf. x264 --fullhelp)) specified for output file #0 (/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_2/TC_00012_0_2_02.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 (h264) -> trim
#   crop -> Stream #0:0 (rawvideo)
# Press [q] to stop, [?] for help
# Output #0, avi, to '/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_2/TC_00012_0_2_02.avi':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 480x480, q=2-31, 82944 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       encoder         : Lavc58.91.100 rawvideo
# frame=  300 fps= 87 q=-0.0 Lsize=  101263kB time=00:00:10.00 bitrate=82954.3kbits/s speed= 2.9x
# video:101250kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.012429%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kyoung/Downloads/TC_00012.MOV':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2022-11-16T07:45:20.000000Z
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#   Duration: 00:22:23.20, start: 0.000000, bitrate: 23680 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x1080, 23677 kb/s, 30 fps, 30 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       creation_time   : 2022-11-16T07:45:21.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
# Codec AVOption preset (Set the encoding preset (cf. x264 --fullhelp)) specified for output file #0 (/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_1/TC_00012_0_1_03.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 (h264) -> trim
#   crop -> Stream #0:0 (rawvideo)
# Press [q] to stop, [?] for help
# Output #0, avi, to '/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_1/TC_00012_0_1_03.avi':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 480x480, q=2-31, 82944 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       encoder         : Lavc58.91.100 rawvideo
# frame=  300 fps= 83 q=-0.0 Lsize=  101263kB time=00:00:10.00 bitrate=82954.3kbits/s speed=2.76x
# video:101250kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.012429%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kyoung/Downloads/TC_00012.MOV':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2022-11-16T07:45:20.000000Z
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#   Duration: 00:22:23.20, start: 0.000000, bitrate: 23680 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x1080, 23677 kb/s, 30 fps, 30 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       creation_time   : 2022-11-16T07:45:21.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
# Codec AVOption preset (Set the encoding preset (cf. x264 --fullhelp)) specified for output file #0 (/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_2/TC_00012_0_2_03.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 (h264) -> trim
#   crop -> Stream #0:0 (rawvideo)
# Press [q] to stop, [?] for help
# Output #0, avi, to '/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_2/TC_00012_0_2_03.avi':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 480x480, q=2-31, 82944 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       encoder         : Lavc58.91.100 rawvideo
# frame=  300 fps= 86 q=-0.0 Lsize=  101263kB time=00:00:10.00 bitrate=82954.3kbits/s speed=2.86x
# video:101250kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.012429%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kyoung/Downloads/TC_00012.MOV':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2022-11-16T07:45:20.000000Z
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#   Duration: 00:22:23.20, start: 0.000000, bitrate: 23680 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x1080, 23677 kb/s, 30 fps, 30 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       creation_time   : 2022-11-16T07:45:21.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
# Codec AVOption preset (Set the encoding preset (cf. x264 --fullhelp)) specified for output file #0 (/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_1/TC_00012_0_1_04.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 (h264) -> trim
#   crop -> Stream #0:0 (rawvideo)
# Press [q] to stop, [?] for help
# Output #0, avi, to '/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_1/TC_00012_0_1_04.avi':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 480x480, q=2-31, 82944 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       encoder         : Lavc58.91.100 rawvideo
# frame=  300 fps= 98 q=-0.0 Lsize=  101263kB time=00:00:10.00 bitrate=82954.3kbits/s speed=3.26x
# video:101250kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.012429%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kyoung/Downloads/TC_00012.MOV':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2022-11-16T07:45:20.000000Z
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#   Duration: 00:22:23.20, start: 0.000000, bitrate: 23680 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x1080, 23677 kb/s, 30 fps, 30 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       creation_time   : 2022-11-16T07:45:21.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
# Codec AVOption preset (Set the encoding preset (cf. x264 --fullhelp)) specified for output file #0 (/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_2/TC_00012_0_2_04.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 (h264) -> trim
#   crop -> Stream #0:0 (rawvideo)
# Press [q] to stop, [?] for help
# Output #0, avi, to '/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_2/TC_00012_0_2_04.avi':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 480x480, q=2-31, 82944 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       encoder         : Lavc58.91.100 rawvideo
# frame=  300 fps= 82 q=-0.0 Lsize=  101263kB time=00:00:10.00 bitrate=82954.3kbits/s speed=2.74x
# video:101250kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.012429%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kyoung/Downloads/TC_00012.MOV':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2022-11-16T07:45:20.000000Z
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#   Duration: 00:22:23.20, start: 0.000000, bitrate: 23680 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x1080, 23677 kb/s, 30 fps, 30 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       creation_time   : 2022-11-16T07:45:21.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
# Codec AVOption preset (Set the encoding preset (cf. x264 --fullhelp)) specified for output file #0 (/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_1/TC_00012_0_1_05.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 (h264) -> trim
#   crop -> Stream #0:0 (rawvideo)
# Press [q] to stop, [?] for help
# Output #0, avi, to '/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_1/TC_00012_0_1_05.avi':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 480x480, q=2-31, 82944 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       encoder         : Lavc58.91.100 rawvideo
# frame=  300 fps= 75 q=-0.0 Lsize=  101263kB time=00:00:10.00 bitrate=82954.3kbits/s speed=2.49x
# video:101250kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.012429%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kyoung/Downloads/TC_00012.MOV':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2022-11-16T07:45:20.000000Z
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#   Duration: 00:22:23.20, start: 0.000000, bitrate: 23680 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x1080, 23677 kb/s, 30 fps, 30 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       creation_time   : 2022-11-16T07:45:21.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
# Codec AVOption preset (Set the encoding preset (cf. x264 --fullhelp)) specified for output file #0 (/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_2/TC_00012_0_2_05.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 (h264) -> trim
#   crop -> Stream #0:0 (rawvideo)
# Press [q] to stop, [?] for help
# Output #0, avi, to '/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_2/TC_00012_0_2_05.avi':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 480x480, q=2-31, 82944 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       encoder         : Lavc58.91.100 rawvideo
# frame=  300 fps= 75 q=-0.0 Lsize=  101263kB time=00:00:10.00 bitrate=82954.3kbits/s speed= 2.5x
# video:101250kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.012429%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kyoung/Downloads/TC_00012.MOV':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2022-11-16T07:45:20.000000Z
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#   Duration: 00:22:23.20, start: 0.000000, bitrate: 23680 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x1080, 23677 kb/s, 30 fps, 30 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       creation_time   : 2022-11-16T07:45:21.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
# Codec AVOption preset (Set the encoding preset (cf. x264 --fullhelp)) specified for output file #0 (/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_1/TC_00012_0_1_06.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 (h264) -> trim
#   crop -> Stream #0:0 (rawvideo)
# Press [q] to stop, [?] for help
# Output #0, avi, to '/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_1/TC_00012_0_1_06.avi':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 480x480, q=2-31, 82944 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       encoder         : Lavc58.91.100 rawvideo
# frame=  300 fps= 64 q=-0.0 Lsize=  101263kB time=00:00:10.00 bitrate=82954.3kbits/s speed=2.14x
# video:101250kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.012429%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kyoung/Downloads/TC_00012.MOV':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2022-11-16T07:45:20.000000Z
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#   Duration: 00:22:23.20, start: 0.000000, bitrate: 23680 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x1080, 23677 kb/s, 30 fps, 30 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       creation_time   : 2022-11-16T07:45:21.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
# Codec AVOption preset (Set the encoding preset (cf. x264 --fullhelp)) specified for output file #0 (/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_2/TC_00012_0_2_06.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 (h264) -> trim
#   crop -> Stream #0:0 (rawvideo)
# Press [q] to stop, [?] for help
# Output #0, avi, to '/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_2/TC_00012_0_2_06.avi':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 480x480, q=2-31, 82944 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       encoder         : Lavc58.91.100 rawvideo
# frame=  300 fps= 92 q=-0.0 Lsize=  101263kB time=00:00:10.00 bitrate=82954.3kbits/s speed=3.08x
# video:101250kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.012429%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kyoung/Downloads/TC_00012.MOV':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2022-11-16T07:45:20.000000Z
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#   Duration: 00:22:23.20, start: 0.000000, bitrate: 23680 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x1080, 23677 kb/s, 30 fps, 30 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       creation_time   : 2022-11-16T07:45:21.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
# Codec AVOption preset (Set the encoding preset (cf. x264 --fullhelp)) specified for output file #0 (/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_1/TC_00012_0_1_07.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 (h264) -> trim
#   crop -> Stream #0:0 (rawvideo)
# Press [q] to stop, [?] for help
# Output #0, avi, to '/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_1/TC_00012_0_1_07.avi':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 480x480, q=2-31, 82944 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       encoder         : Lavc58.91.100 rawvideo
# frame=  300 fps=100 q=-0.0 Lsize=  101263kB time=00:00:10.00 bitrate=82954.3kbits/s speed=3.34x
# video:101250kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.012429%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kyoung/Downloads/TC_00012.MOV':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2022-11-16T07:45:20.000000Z
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#   Duration: 00:22:23.20, start: 0.000000, bitrate: 23680 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x1080, 23677 kb/s, 30 fps, 30 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       creation_time   : 2022-11-16T07:45:21.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
# Codec AVOption preset (Set the encoding preset (cf. x264 --fullhelp)) specified for output file #0 (/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_2/TC_00012_0_2_07.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 (h264) -> trim
#   crop -> Stream #0:0 (rawvideo)
# Press [q] to stop, [?] for help
# Output #0, avi, to '/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_2/TC_00012_0_2_07.avi':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 480x480, q=2-31, 82944 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       encoder         : Lavc58.91.100 rawvideo
# frame=  300 fps= 91 q=-0.0 Lsize=  101263kB time=00:00:10.00 bitrate=82954.3kbits/s speed=3.05x
# video:101250kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.012429%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kyoung/Downloads/TC_00012.MOV':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2022-11-16T07:45:20.000000Z
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#   Duration: 00:22:23.20, start: 0.000000, bitrate: 23680 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x1080, 23677 kb/s, 30 fps, 30 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       creation_time   : 2022-11-16T07:45:21.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
# Codec AVOption preset (Set the encoding preset (cf. x264 --fullhelp)) specified for output file #0 (/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_1/TC_00012_0_1_08.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 (h264) -> trim
#   crop -> Stream #0:0 (rawvideo)
# Press [q] to stop, [?] for help
# Output #0, avi, to '/Users/kyoung/Downloads/TC_00012_0/TC_00012_0_1/TC_00012_0_1_08.avi':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 480x480, q=2-31, 82944 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       encoder         : Lavc58.91.100 rawvideo
# frame=  300 fps= 67 q=-0.0 Lsize=  101263kB time=00:00:10.00 bitrate=82954.3kbits/s speed=2.23x
# video:101250kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.012429%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
# ...
#       encoder         : Lavc58.91.100 rawvideo
# frame=  300 fps= 97 q=-0.0 Lsize=  101263kB time=00:00:10.00 bitrate=82954.3kbits/s speed=3.25x
# video:101250kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.012429%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kyoung/Downloads/TC_00012.MOV':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2022-11-16T07:45:20.000000Z
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#   Duration: 00:22:23.20, start: 0.000000, bitrate: 23680 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x1080, 23677 kb/s, 30 fps, 30 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       creation_time   : 2022-11-16T07:45:21.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
# Codec AVOption preset (Set the encoding preset (cf. x264 --fullhelp)) specified for output file #0 (/Users/kyoung/Downloads/TC_00012_20/TC_00012_20_2/TC_00012_20_2_20.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 (h264) -> trim
#   crop -> Stream #0:0 (rawvideo)
# Press [q] to stop, [?] for help
# Output #0, avi, to '/Users/kyoung/Downloads/TC_00012_20/TC_00012_20_2/TC_00012_20_2_20.avi':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 480x480, q=2-31, 82944 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       encoder         : Lavc58.91.100 rawvideo
# frame=  300 fps= 88 q=-0.0 Lsize=  101263kB time=00:00:10.00 bitrate=82954.3kbits/s speed=2.94x
# video:101250kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.012429%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kyoung/Downloads/TC_00012.MOV':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2022-11-16T07:45:20.000000Z
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#   Duration: 00:22:23.20, start: 0.000000, bitrate: 23680 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x1080, 23677 kb/s, 30 fps, 30 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       creation_time   : 2022-11-16T07:45:21.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
# Codec AVOption preset (Set the encoding preset (cf. x264 --fullhelp)) specified for output file #0 (/Users/kyoung/Downloads/TC_00012_20/TC_00012_20_1/TC_00012_20_1_21.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 (h264) -> trim
#   crop -> Stream #0:0 (rawvideo)
# Press [q] to stop, [?] for help
# Output #0, avi, to '/Users/kyoung/Downloads/TC_00012_20/TC_00012_20_1/TC_00012_20_1_21.avi':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 480x480, q=2-31, 82944 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       encoder         : Lavc58.91.100 rawvideo
# frame=  300 fps= 82 q=-0.0 Lsize=  101263kB time=00:00:10.00 bitrate=82954.3kbits/s speed=2.72x
# video:101250kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.012429%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kyoung/Downloads/TC_00012.MOV':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2022-11-16T07:45:20.000000Z
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#   Duration: 00:22:23.20, start: 0.000000, bitrate: 23680 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x1080, 23677 kb/s, 30 fps, 30 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       creation_time   : 2022-11-16T07:45:21.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
# Codec AVOption preset (Set the encoding preset (cf. x264 --fullhelp)) specified for output file #0 (/Users/kyoung/Downloads/TC_00012_20/TC_00012_20_2/TC_00012_20_2_21.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 (h264) -> trim
#   crop -> Stream #0:0 (rawvideo)
# Press [q] to stop, [?] for help
# Output #0, avi, to '/Users/kyoung/Downloads/TC_00012_20/TC_00012_20_2/TC_00012_20_2_21.avi':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 480x480, q=2-31, 82944 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       encoder         : Lavc58.91.100 rawvideo
# frame=  300 fps=100 q=-0.0 Lsize=  101263kB time=00:00:10.00 bitrate=82954.3kbits/s speed=3.35x
# video:101250kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.012429%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kyoung/Downloads/TC_00012.MOV':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2022-11-16T07:45:20.000000Z
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#   Duration: 00:22:23.20, start: 0.000000, bitrate: 23680 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x1080, 23677 kb/s, 30 fps, 30 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       creation_time   : 2022-11-16T07:45:21.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
# Codec AVOption preset (Set the encoding preset (cf. x264 --fullhelp)) specified for output file #0 (/Users/kyoung/Downloads/TC_00012_20/TC_00012_20_1/TC_00012_20_1_22.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 (h264) -> trim
#   crop -> Stream #0:0 (rawvideo)
# Press [q] to stop, [?] for help
# Output #0, avi, to '/Users/kyoung/Downloads/TC_00012_20/TC_00012_20_1/TC_00012_20_1_22.avi':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 480x480, q=2-31, 82944 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       encoder         : Lavc58.91.100 rawvideo
# frame=  246 fps=118 q=-0.0 Lsize=   83036kB time=00:00:08.20 bitrate=82955.3kbits/s speed=3.95x
# video:83025kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.013632%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1627813741069/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kyoung/Downloads/TC_00012.MOV':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2022-11-16T07:45:20.000000Z
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#   Duration: 00:22:23.20, start: 0.000000, bitrate: 23680 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x1080, 23677 kb/s, 30 fps, 30 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       creation_time   : 2022-11-16T07:45:21.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
# Codec AVOption preset (Set the encoding preset (cf. x264 --fullhelp)) specified for output file #0 (/Users/kyoung/Downloads/TC_00012_20/TC_00012_20_2/TC_00012_20_2_22.avi) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 (h264) -> trim
#   crop -> Stream #0:0 (rawvideo)
# Press [q] to stop, [?] for help
# Output #0, avi, to '/Users/kyoung/Downloads/TC_00012_20/TC_00012_20_2/TC_00012_20_2_22.avi':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.quicktime.location.ISO6709: +37.34936+127.94590+153CRSWGS_84
#     com.apple.quicktime.software: TimeStamp Camera
#     com.apple.quicktime.make: Apple
#     ISFT            : Lavf58.45.100
#     Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 480x480, q=2-31, 82944 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       encoder         : Lavc58.91.100 rawvideo
# frame=  246 fps= 85 q=-0.0 Lsize=   83036kB time=00:00:08.20 bitrate=82955.3kbits/s speed=2.82x
# video:83025kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.013632%
